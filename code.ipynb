# %%
print("hello world")
# Out:
# hello world

# %%
import sys
print(sys.version)
# Out:
# 3.9.6 (default, May  7 2023, 23:32:44)
# [Clang 14.0.3 (clang-1403.0.22.14.1)]

# %% [markdown]
# 1. Operacje arytmentyczne

# %%
a = 15+8
b = 100-37
6*7
# Out:
# 42

# %%
import math

# %%
abs(-42)
math.sqrt(225)

print(2 ** 8)
# Out:
# 256

# %%
pip install numpy
import numpy as np

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 24.1.1 -> 26.0.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -- upgrade pip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not find a version that satisfies the requirement upgrade (from versions: none)
# ERROR: No matching distribution found for upgrade
#
# [notice] A new release of pip is available: 24.1.1 -> 26.0.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/__init__.py:22
#      19 del _hard_dependencies, _dependency, _missing_dependencies
#      21 # numpy compat
# ---> 22 from pandas.compat import is_numpy_dev as _is_numpy_dev  # pyright: ignore # noqa:F401
#      24 try:
#      25     from pandas._libs import hashtable as _hashtable, lib as _lib, tslib as _tslib
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/compat/__init__.py:18
#      15 from typing import TYPE_CHECKING
#      17 from pandas._typing import F
# ---> 18 from pandas.compat.numpy import (
#      19     is_numpy_dev,
#      20     np_version_under1p21,
#      21 )
#      22 from pandas.compat.pyarrow import (
#      23     pa_version_under1p01,
#      24     pa_version_under2p0,
#    (...)
# ...
