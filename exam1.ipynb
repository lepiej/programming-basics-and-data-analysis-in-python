# %%
produkt = {
    'kategoria': 'AGD',
    'produkt': 'pralka',
    'cena': 5600,
    'funkcje_urządzenia': [{'czyszczenie_1': 'wolne', 'czyszczenie_2': 'szybkie'}
    , 'szybki_15min', 'pranie']
}

# %%
print("1. typ zmiennej produkt:", type(produkt))
# Out:
# 1. typ zmiennej produkt: <class 'dict'>

# %%
print("2. typ obiektu pod kluczem funkcje_urządzenia:", type(produkt['funkcje_urządzenia']))
# Out:
# 2. typ obiektu pod kluczem funkcje_urządzenia: <class 'list'>

# %%
print("3. typ pierwszego obiektu pod kluczem funkcje_urządzenia:", type(produkt['funkcje_urządzenia'][0]))
# Out:
# 3. typ pierwszego obiektu pod kluczem funkcje_urządzenia: <class 'dict'>
