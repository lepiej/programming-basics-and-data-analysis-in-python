# %%
print("hello world")
# Out:
# hello world

# %%
import sys
print(sys.version)
# Out:
# 3.9.6 (default, May  7 2023, 23:32:44)
# [Clang 14.0.3 (clang-1403.0.22.14.1)]

# %% [markdown]
# 1. Operacje arytmentyczne

# %%
a = 15+8
b = 100-37
6*7
# Out:
# 42

# %%
import math

# %%
abs(-42)
math.sqrt(225)
code
#VSC-2d998f95
python
try:
    import pandas as pd
except Exception as e:
    import sys, subprocess, importlib
    print('pandas import failed:', e)
    subprocess.check_call([sys.executable, '-m', 'pip', 'install', '--upgrade', 'pip', 'wheel', 'setuptools'])
    subprocess.check_call([sys.executable, '-m', 'pip', 'install', '--upgrade', '--force-reinstall', '--no-cache-dir', 'numpy', 'pandas'])
    importlib.invalidate_caches()
    import pandas as pd
print('pandas version:', pd.__version__)

source
subprocess.check_call([sys.executable, '-m', 'pip', 'install', '--upgrade', '--force-reinstall', '--no-cache-dir', 'numpy', 'pandas', '--prefer-binary'])
print('install_complete')
# Out:
# 256

# %%
# ensure a clean, compatible pandas is installed in the kernel environment
# %pip install --upgrade --force-reinstall --no-cache-dir pandas
import pandas as pd
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 2.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 9.8 MB/s eta 0:00:00:00:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 8.9 MB/s eta 0:00:00a 0:00:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 509.2/509.2 kB 10.6 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 348.5/348.5 kB 12.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2025.2
#     Uninstalling pytz-2025.2:
#       Successfully uninstalled pytz-2025.2
#   Attempting uninstall: tzdata
#     Found existing installation: tzdata 2025.3
#     Uninstalling tzdata-2025.3:
#       Successfully uninstalled tzdata-2025.3
# ...
